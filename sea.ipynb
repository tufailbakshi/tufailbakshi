# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\tufai\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\tufai\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\tufai\appdata\local\programs\python\python314\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tufai\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tufai\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tufai\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tufai\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tufai\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\tufai\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\tufai\appdata\local\programs\python\python314\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tufai\appdata\roaming\python\python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\tufai\appdata\local\programs\python\python314\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\tufai\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
data = sns.load_dataset ("diamonds")
df1 = data.head(10)

# %%
sns.lineplot(x='carat',y='price',data=df1,hue='cut')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
import seaborn as sns
import pandas as pd

# %%
data = {
    "subject":['Math','Math','Science','Science','English','English'],
    "gender":['Male','Female','Male','Female','Male','Female'],
    "marks":[70,83,63,33,61,79]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    subject  gender  marks
# 0     Math    Male     70
# 1     Math  Female     83
# 2  Science    Male     63
# 3  Science  Female     33
# 4  English    Male     61
# 5  English  Female     79

# %%
sns.barplot(x='subject',y='marks',data=df,hue='gender')
# Out:
# <Axes: xlabel='subject', ylabel='marks'>

# %%
data = sns.load_dataset("titanic")

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.stripplot(x='survived', y='age',data=data,hue='pclass',palette='rainbow')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.countplot(x='sex',data=data,color='yellow')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
d1 = sns.load_dataset("tips")

# %%
d1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxenplot(x='day',y='total_bill', data=d1,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
 data = sns.load_dataset('flights')

# %%
data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
p_table =data.pivot(index = 'year', columns = 'month', values = 'passengers')
sns.heatmap(p_table, annot=True, fmt='.0f', cmap='YlGnBu')
# Out:
# <Axes: xlabel='month', ylabel='year'>

# %%
d1 = sns .load_dataset("titanic")

# %%
sns.pairplot(data = d1, hue ='sex')
