# %%
import pandas as pd

# %%
import pandas as pd

# %%
data = pd.read_csv("netflix_titles.csv")

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data [['show_id' , 'duration']]
# Out:
#        show_id    duration
# 0     81145628      90 min
# 1     80117401      94 min
# 2     70234439    1 Season
# 3     80058654    1 Season
# 4     80125979      99 min
# ...        ...         ...
# 6229  80000063  13 Seasons
# 6230  70286564   4 Seasons
# 6231  80116008      60 min
# 6232  70281022   2 Seasons
# 6233  70153404  10 Seasons
#
# [6234 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6234 entries, 0 to 6233
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6234 non-null   int64
#  1   type          6234 non-null   str
#  2   title         6234 non-null   str
#  3   director      4265 non-null   str
#  4   cast          5664 non-null   str
#  5   country       5758 non-null   str
#  6   date_added    6223 non-null   str
#  7   release_year  6234 non-null   int64
#  8   rating        6224 non-null   str
#  9   duration      6234 non-null   str
#  10  listed_in     6234 non-null   str
#  11  description   6234 non-null   str
# dtypes: int64(2), str(10)
# memory usage: 584.6 KB

# %%
data ['type'].value_counts()
# Out:
# type
# Movie      4265
# TV Show    1969
# Name: count, dtype: int64

# %% [markdown]
# *filtration*

# %%
data[data['release_year']==2020]
# Out:
#        show_id     type                                              title  \
# 1315  81034946  TV Show                                 Maradona in Mexico
# 3180  81214114    Movie                                      Bulletproof 2
# 3189  81039393  TV Show                                              Cheer
# 3195  80233408    Movie                              Live Twice, Love Once
# 3220  80997687  TV Show                                            Dracula
# 3221  80237347  TV Show                                Go! Go! Cory Carson
# 3249  81006825    Movie                      All the Freckles in the World
# 3325  81160763  TV Show                                     Sex, Explained
# 3352  81127902    Movie                                  A Fall from Grace
# 3353  80995039  TV Show                                               Ares
# 3354  81062580  TV Show                                 Nailed It! Germany
# ...

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='str')

# %%
data ['country'].nunique()
# Out:
# 554

# %%
data[data['country'].str.contains('554')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data['country'].isnull().sum()
# Out:
# np.int64(476)

# %%
data['country'] = data['country'].fillna('no value')

# %%
data[data['country'].str.contains('no value')]
# Out:
#        show_id     type                                           title  \
# 10    80169755    Movie                     Joaquín Reyes: Una y no más
# 12    80182480    Movie                        Krish Trish and Baltiboy
# 13    80182483    Movie        Krish Trish and Baltiboy: Battle of Wits
# 14    80182596    Movie  Krish Trish and Baltiboy: Best Friends Forever
# 15    80182482    Movie       Krish Trish and Baltiboy: Comics of India
# ...        ...      ...                                             ...
# 6170  80136456  TV Show                                    Age of Glory
# 6195  80136790  TV Show                                  Goodnight DJ 1
# 6199  80244228  TV Show                          Beauty and the Bitches
# 6228  80159925  TV Show                                        Kikoriki
# 6231  80116008    Movie          Little Baby Bum: Nursery Rhyme Friends
#
#                          director  \
# 10          José Miguel Contreras
# ...

# %%
data['First_actor'] = data['cast'].str.split(',,').str[1]
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data = pd.read_csv("netflix_titles.csv")

# %%
data.groupby('release_year')['title'].count()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       3
#         ...
# 2016     830
# 2017     959
# 2018    1063
# 2019     843
# 2020      25
# Name: title, Length: 72, dtype: int64

# %%
data[data['title'].str.contains("love")]
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country date_added  release_year  \
# ...

# %%
data[data['director'].str.contains('Gaspar Noe')]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data['release_year'].min()
# Out:
# np.int64(1925)

# %%
data['release_year'].max()
# Out:
# np.int64(2020)

# %%
data[(data['release_year']==2020)&
     (data['type']=='TV Show')
     ]
# Out:
#        show_id     type                                              title  \
# 1315  81034946  TV Show                                 Maradona in Mexico
# 3189  81039393  TV Show                                              Cheer
# 3220  80997687  TV Show                                            Dracula
# 3221  80237347  TV Show                                Go! Go! Cory Carson
# 3325  81160763  TV Show                                     Sex, Explained
# 3353  80995039  TV Show                                               Ares
# 3354  81062580  TV Show                                 Nailed It! Germany
# 3363  80996973  TV Show                                  Handsome Siblings
# 3379  81062828  TV Show         Killer Inside: The Mind of Aaron Hernandez
# 3426  80221553  TV Show                   Kipo and the Age of Wonderbeasts
# 3436  80239306  TV Show                         The Healing Powers of Dude
# ...

# %%
data[
    (data['country']=='United States')&
    (data['type']=='TV Show')
]
# Out:
#        show_id     type                             title director  \
# 2     70234439  TV Show                Transformers Prime      NaN
# 3     80058654  TV Show  Transformers: Robots in Disguise      NaN
# 8     80117902  TV Show                      Fire Chasers      NaN
# 54    80113482  TV Show                       No Tomorrow      NaN
# 61    80113641  TV Show                         Frequency      NaN
# ...        ...      ...                               ...      ...
# 6225  70153412  TV Show                           Frasier      NaN
# 6226  70243132  TV Show               La Familia P. Luche      NaN
# 6229  80000063  TV Show                      Red vs. Blue      NaN
# 6230  70286564  TV Show                             Maron      NaN
# 6233  70153404  TV Show                           Friends      NaN
#
#                                                    cast        country  \
# 2     Peter Cullen, Sumalee Montano, Frank Welker, J...  United States
# ...

# %%
data[data['director'].str.contains('Gaspar Noé')]
# Out:
#      show_id   type title    director  \
# 19  80057969  Movie  Love  Gaspar Noé
#
#                                                  cast          country  \
# 19  Karl Glusman, Klara Kristin, Aomi Muyock, Ugo ...  France, Belgium
#
#            date_added  release_year rating duration  \
# 19  September 8, 2017          2015     NR  135 min
#
#                                   listed_in  \
# 19  Cult Movies, Dramas, Independent Movies
#
#                                           description
# 19  A man in an unsatisfying marriage recalls the ...

# %%
data['date_added'] = pd.to_datetime(data['date_added'].str.strip())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data['date_added'] = pd.to_datetime(data['date_added'].str.strip())
#
# File c:\Users\tufai\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6199 if (
#    6200     name not in self._internal_names_set
#    6201     and name not in self._metadata
#    6202     and name not in self._accessors
#    6203     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204 ):
#    6205     return self[name]
# -> 6206 return object.__getattribute__(self, name)
#
# File c:\Users\tufai\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
data.head(10)
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
# 5  80163890  TV Show                                  Apaches
# 6  70304989    Movie                                 Automata
# 7  80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 8  80117902  TV Show                             Fire Chasers
# 9  70304990    Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                 Fernando Lebrija
# 5                              NaN
# ...

# %%
data['rating'].value_counts()
# Out:
# rating
# TV-MA       2027
# TV-14       1698
# TV-PG        701
# R            508
# PG-13        286
# NR           218
# PG           184
# TV-Y7        169
# TV-G         149
# TV-Y         143
# TV-Y7-FV      95
# G             37
# UR             7
# NC-17          2
# Name: count, dtype: int64

# %%
data.groupby('country')['type'].value_counts()
# Out:
# country                                              type
# Argentina                                            Movie      26
#                                                      TV Show    12
# Argentina, Brazil, France, Poland, Germany, Denmark  Movie       1
# Argentina, Chile                                     Movie       1
# Argentina, Chile, Peru                               Movie       1
#                                                                 ..
# Uruguay, Spain, Mexico                               Movie       1
# Venezuela                                            Movie       1
# Venezuela, Colombia                                  Movie       1
# Vietnam                                              Movie       4
# West Germany                                         Movie       1
# Name: count, Length: 636, dtype: int64

# %%
data[data['cast'].str.contains("Shah Rukh Khan")]
# Out:
#        show_id   type                                              title  \
# 533   81121023  Movie  My Next Guest with David Letterman and Shah Ru...
# 1649  80164778  Movie                                              Raees
# 1686  81005364  Movie                                               Zero
# 1761  80157133  Movie                                          Chamatkar
# 1764  80157083  Movie                               Kabhi Haan Kabhi Naa
# 1767  24081514  Movie                                          Ram Jaane
# 1884  80158395  Movie                                            Chaahat
# 1890  20764666  Movie                              English Babu Desi Mem
# 2216  60021758  Movie                                              Asoka
# 2221  80156935  Movie                                         One 2 Ka 4
# 2335  17671454  Movie                                             Dil Se
# 2363  80059049  Movie                                             Pardes
# ...

# %%
data['director'].value_counts().head()
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              14
# Jay Karas                 13
# Jay Chapman               12
# Martin Scorsese            9
# Name: count, dtype: int64

# %%
data[(data['type']=='Movie')&
     (data['release_year']>2018)
     ]
# Out:
#        show_id   type                                             title  \
# 0     81145628  Movie           Norm of the North: King Sized Adventure
# 35    81154455  Movie                                        Article 15
# 38    81132437  Movie                               Kill Me If You Dare
# 44    81176188  Movie  American Factory: A Conversation with the Obamas
# 57    81078908  Movie                                 The World We Make
# ...        ...    ...                                               ...
# 5451  81041272  Movie          Francesco De Carlo: Cose di Questo Mondo
# 5455  81019888  Movie                                  The Perfect Date
# 5463  81026007  Movie                 Liss Pereira: Reteniendo líquidos
# 5464  81021447  Movie                                       The Silence
# 5469  81086434  Movie                                               706
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 35               Anubhav Sinha
# ...

# %%
data ['type'].value_counts()
# Out:
# type
# Movie      4265
# TV Show    1969
# Name: count, dtype: int64

# %%
data['release_year'].max()
# Out:
# np.int64(2020)

# %%
data[data['type']=='Movie']['release_year'].max()
# Out:
# np.int64(2020)

# %%
data['release_year'].unique()
# Out:
# array([2019, 2016, 2013, 2017, 2014, 2015, 2009, 2012, 2010, 2018, 2011,
#        2004, 2000, 1983, 1982, 2006, 2005, 2002, 1997, 2008, 2007, 2003,
#        1981, 1991, 1994, 1988, 1976, 1973, 1974, 1989, 1986, 1984, 1978,
#        1998, 1972, 1979, 1960, 1959, 2001, 1995, 1992, 1990, 1975, 1985,
#        1980, 1970, 1996, 1967, 1999, 1987, 1968, 1993, 2020, 1958, 1965,
#        1956, 1962, 1955, 1977, 1945, 1946, 1942, 1944, 1947, 1943, 1969,
#        1954, 1966, 1971, 1964, 1925, 1963])

# %%
data.describe()
# Out:
#             show_id                  date_added  release_year
# count  6.234000e+03                        6223    6234.00000
# mean   7.670368e+07  2018-07-01 15:36:42.346135    2013.35932
# min    2.477470e+05         2008-01-01 00:00:00    1925.00000
# 25%    8.003580e+07         2017-10-01 00:00:00    2013.00000
# 50%    8.016337e+07         2018-09-30 00:00:00    2016.00000
# 75%    8.024489e+07         2019-06-08 00:00:00    2018.00000
# max    8.123573e+07         2020-01-18 00:00:00    2020.00000
# std    1.094296e+07                         NaN       8.81162
