# %%
# !pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# # key data structure in pandas are #
# **  1 SERIES
# **  2 DATA FRAME

# %%
gh = pd.Series([1, 2, 3, 4, 5])
print(gh)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
dt = [ 2, 3, 4, 5, 6, 7, 8, 9, 10 ]
s = pd.Series(dt)
print(s)
# Out:
# 0     2
# 1     3
# 2     4
# 3     5
# 4     6
# 5     7
# 6     8
# 7     9
# 8    10
# dtype: int64

# %%
x = {
    "name": ['Ali', 'Ahmet', 'Ayşe', 'Fatma', 'Mehmet'],
    "age": [25, 30, 22, 28, 35],
    "roll-no": [1, 2, 3, 4, 5]
}
df = pd.DataFrame(x)
print(df)
# Out:
#      name  age  roll-no
# 0     Ali   25        1
# 1   Ahmet   30        2
# 2    Ayşe   22        3
# 3   Fatma   28        4
# 4  Mehmet   35        5

# %%
import pandas as pd

# %%
df= pd.read_csv("train.csv")

# %%
df.head(7)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.tail(7)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch           Ticket    Fare Cabin Embarked
# 884    male  25.0      0      0  SOTON/OQ 392076   7.050   NaN        S
# 885  female  39.0      0      5           382652  29.125   NaN        Q
# 886    male  27.0      0      0           211536  13.000   NaN        S
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.shape
# Out:
# (891, 12)

# %%
import pandas as pd

# %%
data= pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.loc[:, 'Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: str

# %%
data.iloc[1,3]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")
print (data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## sort
# ** here we can sort the elememts by ascending and decending order

# %%
data.sort_values(by= "PassengerId", ascending=False)
data = data[data['Parch'] == 2]
data .head()
# Out:
#     PassengerId  Survived  Pclass  \
# 8             9         1       3
# 27           28         0       1
# 43           44         1       2
# 58           59         1       2
# 59           60         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 58                       West, Miss. Constance Mirium  female   5.0      1
# 59                 Goodwin, Master. William Frederick    male  11.0      5
#
#     Parch         Ticket      Fare        Cabin Embarked
# 8       2         347742   11.1333          NaN        S
# 27      2          19950  263.0000  C23 C25 C27        S
# 43      2  SC/Paris 2123   41.5792          NaN        C
# 58      2     C.A. 34651   27.7500          NaN        S
# ...

# %% [markdown]
# ## count
# ** helps us to count the data of any row and colomn

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    355
# 1    186
# 2    173
# Name: count, dtype: int64

# %%
data['Survived']= data['Survived'].map({0:'Alive',1:'Dead'})
data.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1      NaN       3
# 1            2      NaN       1
# 2            3      NaN       3
# 3            4      NaN       1
# 4            5      NaN       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data = pd.read_csv("train.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data = data[(data['Age'] ==10) & (data['Age'] > 20)]
if data.empty:
    print("No age is in the specified range.")
data.head()
# Out:
# No age is in the specified range.
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# import pandas as pd

# %%
data = pd.read_csv("train.csv")

# %%
data['Survived']= data['Survived'].map({0:'Alive',1:'Dead'})
data.tail()
# Out:
#      PassengerId Survived  Pclass                                      Name  \
# 886          887    Alive       2                     Montvila, Rev. Juozas
# 887          888     Dead       1              Graham, Miss. Margaret Edith
# 888          889    Alive       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890     Dead       1                     Behr, Mr. Karl Howell
# 890          891    Alive       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## DROPNA
# HELPS US TO DELETE NULL VALUES

# %%
data.dropna(subset=['Age'], inplace=True)
data.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1      NaN       3
# 1            2      NaN       1
# 2            3      NaN       3
# 3            4      NaN       1
# 4            5      NaN       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data[(data['Age']>30)&
     (data['Sex']=='male')&
     (data['Survived']=='Alive')
     ]
data.head(12)
# Out:
#     PassengerId Survived  Pclass  \
# 0             1      NaN       3
# 1             2      NaN       1
# 2             3      NaN       3
# 3             4      NaN       1
# 4             5      NaN       3
# 6             7      NaN       1
# 7             8      NaN       3
# 8             9      NaN       3
# 9            10      NaN       2
# 10           11      NaN       3
# 11           12      NaN       1
# 12           13      NaN       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data['Age']= data['Age'].fillna(data['Age'].mean())
data['Age'].isnull().sum()
data.head(100)
# Out:
#      PassengerId Survived  Pclass  \
# 0              1      NaN       3
# 1              2      NaN       1
# 2              3      NaN       3
# 3              4      NaN       1
# 4              5      NaN       3
# ..           ...      ...     ...
# 120          121      NaN       2
# 122          123      NaN       2
# 123          124      NaN       2
# 124          125      NaN       1
# 125          126      NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.sort_values(by=['Age','Fare'])
# Out:
#      PassengerId Survived  Pclass                                  Name  \
# 803          804      NaN       3       Thomas, Master. Assad Alexander
# 755          756      NaN       2             Hamalainen, Master. Viljo
# 469          470      NaN       3         Baclini, Miss. Helene Barbara
# 644          645      NaN       3                Baclini, Miss. Eugenie
# 831          832      NaN       2       Richards, Master. George Sibley
# ..           ...      ...     ...                                   ...
# 116          117      NaN       3                  Connors, Mr. Patrick
# 96            97      NaN       1             Goldschmidt, Mr. George B
# 493          494      NaN       1               Artagaveytia, Mr. Ramon
# 851          852      NaN       3                   Svensson, Mr. Johan
# 630          631      NaN       1  Barkworth, Mr. Algernon Henry Wilson
#
#         Sex    Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# here it filters the particular column

# %%
data[data['Survived'].isin(['Alive'])]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data = pd.read_csv("train.csv")
print (data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# here wetration and sorting together

# %%
data[data['Age']>30].sort_values(by="Age")
# Out:
#      PassengerId  Survived  Pclass  \
# 767          768         0       3
# 814          815         0       3
# 801          802         1       2
# 805          806         0       3
# 817          818         0       2
# ..           ...       ...     ...
# 116          117         0       3
# 493          494         0       1
# 96            97         0       1
# 851          852         0       3
# 630          631         1       1
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 767                           Mangan, Miss. Mary  female  30.5      0      0
# 814                   Tomlin, Mr. Ernest Portage    male  30.5      0      0
# 801  Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.0      1      1
# 805                    Johansson, Mr. Karl Johan    male  31.0      0      0
# 817                           Mallet, Mr. Albert    male  31.0      1      1
# ...

# %% [markdown]
# here we filter byu string value

# %%
data[data['Name'].str.contains('John Bradley')]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %%
import pandas as pd

# %% [markdown]
# data.loc is used to find any elements with the help of indexing

# %%
data.loc[0,'Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %% [markdown]
# data. iloc is used to update any string value with the help of indexing

# %%
data.iloc[0,3] = 'sahil'
data.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                                                sahil    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data.iloc[0,3]
# Out:
# 'sahil'

# %% [markdown]
# is used to replace any string value

# %%
data.replace('Cumings, Mrs. John Bradley (Florence Briggs Thayer)','zibran')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                           sahil    male  22.0      1      0
# 1                                          zibran  female  38.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# ...

# %%
data.replace('A/5 21171	),by','A/5 23636')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                                                sahil    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.iloc[0,3] = 'A/5 879788'
data.head
# Out:
# <bound method NDFrame.head of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name         Sex  \
# PassengerId
# 1                                                   A/5 879788  A/5 879788
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      female
# 3                                       Heikkinen, Miss. Laina      female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      female
# 5                                     Allen, Mr. William Henry        male
# ...                                                        ...         ...
# ...

# %%
data.rename(columns={'Sex':'Gender'},inplace=True)
data.head
# Out:
# <bound method NDFrame.head of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name      Gender  \
# PassengerId
# 1                                                   A/5 879788  A/5 879788
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...      female
# 3                                       Heikkinen, Miss. Laina      female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)      female
# 5                                     Allen, Mr. William Henry        male
# ...                                                        ...         ...
# ...

# %%
data.sort_values(by='Age')
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 804                 1       3           Thomas, Master. Assad Alexander
# 756                 1       2                 Hamalainen, Master. Viljo
# 645                 1       3                    Baclini, Miss. Eugenie
# 470                 1       3             Baclini, Miss. Helene Barbara
# 79                  1       2             Caldwell, Master. Alden Gates
# ...               ...     ...                                       ...
# 860                 0       3                          Razi, Mr. Raihed
# 864                 0       3         Sage, Miss. Dorothy Edith "Dolly"
# 869                 0       3               van Melkebeke, Mr. Philemon
# 879                 0       3                        Laleff, Mr. Kristo
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#              Gender   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# PassengerId
# ...

# %%
data['Gender'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data['Gender'].value_counts()
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

# %%
pd.read_csv('train.csv')
data.head
# Out:
# <bound method NDFrame.head of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data = pd.read_csv("train.csv")

# %%
data[data['Name'].str.contains('<A')]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data[data['Name'].str.contains('Graham, Miss. Margaret Edith')]
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 887          888         1       1  Graham, Miss. Margaret Edith  female
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 887  19.0      0      0  112053  30.0   B42        S

# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ** groupby is used to group rows and columns and perform calculations

# %%
data.groupby('Sex')['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %% [markdown]
# *keyerror means column name you  wrotes not exist in the dataset*

# %%
data.groupby ('sex') ['survived'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 data.groupby ('sex') ['survived'].sum()
#
# File c:\Users\tufai\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\tufai\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
# ...

# %%
data.groupby ('Sex').sum()
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# female       135343       233     678
# male         262043       109    1379
#
#                                                      Name       Age  SibSp  \
# Sex
# female  Cumings, Mrs. John Bradley (Florence Briggs Th...   7286.00    218
# male    Braund, Mr. Owen HarrisAllen, Mr. William Henr...  13919.17    248
#
#         Parch                                             Ticket        Fare  \
# Sex
# female    204  PC 17599STON/O2. 3101282113803347742237736PP 9...  13966.6628
# male      136  A/5 2117137345033087717463349909A/5. 215134708...  14727.2865
#
#                                                     Cabin  \
# Sex
# female  C85C123G6C103B78D33B28F33C23 C25 C27E101F E69D...
# male    E46D56A6C23 C25 C27B30C52C83F G73E31A5D10 D12D...
#
#                                                  Embarked
# Sex
# female  CSSSCSSSSSCQSSQCQSCSSCQQSCSSSSSSSQSSSSSSQCSCSS...
# male    SSQSSSSQSSSSCSSCSCSCSCSQCSSCSCSCSSCCSSSSCSSSSS...

# %%
data.groupby ('Sex')['Survived_0'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 data.groupby ('Sex')['Survived_0'].sum()
#
# File c:\Users\tufai\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\groupby\generic.py:2938, in DataFrameGroupBy.__getitem__(self, key)
#    2931 if isinstance(key, tuple) and len(key) > 1:
#    2932     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    2933     # valid syntax, so don't raise
#    2934     raise ValueError(
#    2935         "Cannot subset columns with a tuple with more than one element. "
#    2936         "Use a list instead."
#    2937     )
# -> 2938 return super().__getitem__(key)
#
# File c:\Users\tufai\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\base.py:228, in SelectionMixin.__getitem__(self, key)
#     226 else:
#     227     if key not in self.obj:
# ...

# %%
data.loc[:, 'Survived']
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data['Survived']
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
data.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
data['Survived'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64>

# %%
data.groupby('Sex')['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
df= pd.read_csv("train.csv")

# %%
import pandas as pd

# %%
data = pd.read_csv("netflix_titles.csv")

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...
